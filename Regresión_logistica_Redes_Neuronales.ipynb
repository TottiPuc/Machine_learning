# %% [markdown]
# <a href="https://colab.research.google.com/github/TottiPuc/Machine_learning/blob/master/Regresi%C3%B3n_logistica_Redes_Neuronales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regresión Logistica para Clasificación de Imágenes

# %% [markdown]
# En un notebook anterior "[clasificación con Keras](https://github.com/TottiPuc/Machine_learning/blob/master/Clasificaci%C3%B3n_NN_feedforward_Keras.ipynb)" fue  implementado un modelo de calsificación de imágenes usando KERAS una herramienta muy poderosa que hace parte de tensorflow y que nos facilita la vida en terminos de programación.
#
# En este notebook se implementara paso  a paso el algoritmo de regresión logistica el cual tiene como objetivo buscar la probabilidad de que un dado elemento pertenezca a una determinada clase, ( a manera informativa esta etapa de regresión logistica es la que se implementa al final de caulquier tipo de red neuronal sea normal o de profundidad DEEP)
#
# El objetivo es mostrar cada una de las etapas de la red neuronal y todos los pasos matematicos para una mejor comprehension los cuales son:
#
#
#
# *   Inicialización de pesos
# *   Cálculo del error entre la imágen original y la estimada
# *   Cálculo de la derivada de la funcion de error
# *   Entrenamiento y evaluación del modelo implementado
#
#
#
# Primero importamos nuestras librerias correspondientes

# %%
# %tensorflow_version 2.x

# %%
import tensorflow as tf
import math
from tensorflow.keras.datasets import fashion_mnist
import pandas as pd
from tqdm import tqdm_notebook

# %% [markdown]
# Como primera medida importamos y hacemos el procesamiento adecuado del dataset fashion MNIST disponible en keras y publicado en [fashion MNIST](https://github.com/zalandoresearch/fashion-mnist)

# %% [markdown]
# ##Cargando datos

# %%
(x_entrenamiento, y_entrenamiento),(x_teste,y_teste) = fashion_mnist.load_data()
#Normalizamos las imagenes para que qeuden en el rango entre 0 y 1 el valor de cada pixel
x_entrenamiento, x_teste = x_entrenamiento/255.0 , x_teste/255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
print("dimensiones de los datos de entrenamiento ", x_entrenamiento.shape)
print("dimensiones de los atiquetas de entrenamiento ", y_entrenamiento.shape)
print("dimensiones de los datos de teste ", x_teste.shape)
# Out:
# dimensiones de los datos de entrenamiento  (60000, 28, 28)
# dimensiones de los atiquetas de entrenamiento  (60000,)
# dimensiones de los datos de teste  (10000, 28, 28)

# %% [markdown]
# Como la entrada de toda red neuronal osea su primera capa de neurones recibe cada matriz de pixeles, es necesario convertir la matriz en un vector.
# En nuestro caso cada matriz es de 28x28 lo que haremos es convertir esta entrada en un vector de 1x784

# %%
x_entrenamiento = tf.reshape(x_entrenamiento,shape=(-1,784))
x_teste = tf.reshape(x_teste,shape=(-1,784))

# %% [markdown]
# ##Creando el modelo

# %% [markdown]
# Lo primero que se hace en todo tipo de modelo es iniciar los pesos del modelo para que no inicien en cero que no es recomendable, y se deben iniciar con valores muy pequeños

# %%
pesos = tf.Variable(tf.random.normal(shape =(784,10), dtype=tf.float64)) # se da esta dmensión para que al multiplicar cada entrada con los pesos cada valor
                                                                                                # del producto punto tenga un valor diferente, si no todos los pesos serian iguales
bias = tf.Variable(tf.random.normal(shape = (10,), dtype=tf.float64))

# %% [markdown]
# Creamos la función de regresion logistica

# %%
def logistic_regression(x):
    lr = tf.add(tf.matmul(x, pesos), bias)
    return lr

# %% [markdown]
# Creamos la funcion de coste que serà nuestra funcion que minimice los errores en este caso usaremos la funcion de entropia cruzada

# %%
def cross_entropy(y_real, y_pred):
    y_real = tf.one_hot(y_real, 10)
    perdidas = tf.nn.softmax_cross_entropy_with_logits(labels = y_real, logits = y_pred)
    return tf.reduce_mean(perdidas)

# %% [markdown]
# Optimizamos el entrenamiento creando la función del Gradiente

# %%
def gradiente(x, y):
    with tf.GradientTape() as tape:
        y_pred = logistic_regression(x)
        loss_val = cross_entropy(y, y_pred)
    return tape.gradient(loss_val, [pesos, bias])

# %% [markdown]
# #Entrenando el modelo

# %% [markdown]
# Creamos los hiperparametros de nuestro modelo

# %%
numero_de_lotes = 10000
tasa_aprendizaje=0.01
tamaño_lote= 128

# %% [markdown]
# Lo importante en toda etapa de optimización es saber que dirección y si se debe aumentar o disminuir el valor del gradiente a los pesos, para eso se utiliza una funcion de optimizacion del gradiente estocastico

# %%
optimizador = tf.optimizers.SGD(tasa_aprendizaje)

# %% [markdown]
# Dejamos preparado el calculo de los aciertos del modelo

# %%
def aciertos(y_real, y_predicho):
  y_real = tf.cast(y_real, dtype= tf.int32)
  predicciones = tf.cast(tf.argmax(y_predicho, axis=1),dtype=tf.int32)
  predicciones = tf.equal(y_real, predicciones)
  return tf.reduce_mean(tf.cast(predicciones,dtype=tf.float32))

# %% [markdown]
# Un punto importante es saber que como estamos usando el SGD (stochastic gradient dsscent) para optimizar nuestro modelo, no podemos usar el conjunto de entrenamiento completo, primero por que seria una mala practica y segundo por que este metodo esta diseñado para actuar de modo offline es decir con datos de entrada recientes sin necesidad de entrenar todo el modelo cuadno lleguen datos nuevos.
#
# Por eso dividiremos en lotes maspequeños nuestros datos de entrenamiento

# %%
dataset_entrenamiento = tf.data.Dataset.from_tensor_slices((x_entrenamiento, y_entrenamiento))
dataset_entrenamiento = dataset_entrenamiento.repeat().shuffle(x_entrenamiento.shape[0]).batch(tamaño_lote)

# %% [markdown]
# Ciclo de entrenamiento

# %%
for indice_lote, (lote_x_entrenamiento, lote_y_entrenamiento) in enumerate(dataset_entrenamiento.take(numero_de_lotes), 1):

  #calculo del gradientes
  gradientes = gradiente(lote_x_entrenamiento,lote_y_entrenamiento)

  # Otimizamos los pesos con el valor del gradiente
  optimizador.apply_gradients(zip(gradientes, [pesos, bias]))

  #Realizamos una predicción
  y_pred = logistic_regression(lote_x_entrenamiento)

  #calculamos el error
  error = cross_entropy(lote_y_entrenamiento, y_pred)

  #calculamos los aciertos
  acierto = aciertos(lote_y_entrenamiento, y_pred)

  # Print
  print("Número del lote: {}, Error del Modelo: {}, Aciertos en entrenamiento: {}".format (indice_lote, error, acierto))
# Out:
# Streaming output truncated to the last 5000 lines.
# Número del lote: 5002, Error del Modelo: 1.7418909483745806, Aciertos en entrenamiento: 0.6015625
# Número del lote: 5003, Error del Modelo: 1.4290754099479306, Aciertos en entrenamiento: 0.7109375
# Número del lote: 5004, Error del Modelo: 1.261584507148021, Aciertos en entrenamiento: 0.71875
# Número del lote: 5005, Error del Modelo: 1.7532305878753105, Aciertos en entrenamiento: 0.6171875
Aciertos en entrenamiento: 0.6640625
# Número del lote: 5045, Error del Modelo: 1.870893632379361, Aciertos en entrenamiento: 0.6015625
# Número del lote: 5046, Error del Modelo: 1.6600436859145775, Aciertos en entrenamiento: 0.625
# Número del lote: 5047, Error del Modelo: 1.7296355182913454, Aciertos en entrenamiento: 0.6328125
# Número del lote: 5048, Error del Modelo: 1.2866897771789643, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5049, Error del Modelo: 1.4325530656234315, Aciertos en entrenamiento: 0.6875
# Número del lote: 5050, Error del Modelo: 1.7663174730660705, Aciertos en entrenamiento: 0.6484375
# Número del lote: 5051, Error del Modelo: 1.480158022654209, Aciertos en entrenamiento: 0.671875
# Número del lote: 5052, Error del Modelo: 1.4615001709940025, Aciertos en entrenamiento: 0.65625
# Número del lote: 5053, Error del Modelo: 1.7569316789865261, Aciertos en entrenamiento: 0.703125
# Número del lote: 5054, Error del Modelo: 1.8040093223733589, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5055, Error del Modelo: 1.5994260357754526, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5056, Error del Modelo: 1.6051248052323346, Aciertos en entrenamiento: 0.65625
# Número del lote: 5057, Error del Modelo: 1.5857985569802358, Aciertos en entrenamiento: 0.640625
# Número del lote: 5058, Error del Modelo: 1.847796608641841, Aciertos en entrenamiento: 0.6328125
# Número del lote: 5059, Error del Modelo: 1.510921142371032, Aciertos en entrenamiento: 0.7109375
# Número del lote: 5060, Error del Modelo: 2.0147254750973023, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5061, Error del Modelo: 1.300360739996119, Aciertos en entrenamiento: 0.703125
# Número del lote: 5062, Error del Modelo: 1.2873142534211852, Aciertos en entrenamiento: 0.7421875
# Número del lote: 5063, Error del Modelo: 1.523543296139804, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5064, Error del Modelo: 1.2560698119220883, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5065, Error del Modelo: 1.4097945753313375, Aciertos en entrenamiento: 0.6875
# Número del lote: 5066, Error del Modelo: 1.805885416059511, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5067, Error del Modelo: 2.003556064825118, Aciertos en entrenamiento: 0.6484375
# Número del lote: 5068, Error del Modelo: 1.509326583253439, Aciertos en entrenamiento: 0.671875
# Número del lote: 5069, Error del Modelo: 1.4999508879382124, Aciertos en entrenamiento: 0.671875
# Número del lote: 5070, Error del Modelo: 2.0414235540045915, Aciertos en entrenamiento: 0.5625
# Número del lote: 5071, Error del Modelo: 1.2700948060474087, Aciertos en entrenamiento: 0.734375
# Número del lote: 5072, Error del Modelo: 1.2060425541872613, Aciertos en entrenamiento: 0.703125
# Número del lote: 5073, Error del Modelo: 1.622935236638166, Aciertos en entrenamiento: 0.640625
# Número del lote: 5074, Error del Modelo: 1.3251468992740785, Aciertos en entrenamiento: 0.7109375
# Número del lote: 5075, Error del Modelo: 1.7889359996512422, Aciertos en entrenamiento: 0.6484375
# Número del lote: 5076, Error del Modelo: 1.505352486935178, Aciertos en entrenamiento: 0.6328125
# Número del lote: 5077, Error del Modelo: 2.0123574110913798, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5078, Error del Modelo: 1.400491306605722, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5079, Error del Modelo: 1.2612958157340408, Aciertos en entrenamiento: 0.7578125
# Número del lote: 5080, Error del Modelo: 1.455637980704788, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5081, Error del Modelo: 1.8940122972208089, Aciertos en entrenamiento: 0.6796875
# Número del lote: 
Aciertos en entrenamiento: 0.6796875
# Número del lote: 5196, Error del Modelo: 1.6663831056532021, Aciertos en entrenamiento: 0.625
# Número del lote: 5197, Error del Modelo: 2.0861026344435087, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5198, Error del Modelo: 1.9634221678267803, Aciertos en entrenamiento: 0.6171875
# Número del lote: 5199, Error del Modelo: 1.1495195609142994, Aciertos en entrenamiento: 0.7578125
# Número del lote: 5200, Error del Modelo: 1.7074179364060444, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5201, Error del Modelo: 1.5489238979572855, Aciertos en entrenamiento: 0.671875
# Número del lote: 5202, Error del Modelo: 1.5242969188592133, Aciertos en entrenamiento: 0.703125
# Número del lote: 5203, Error del Modelo: 1.4827154784081835, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5204, Error del Modelo: 1.7510158539803582, Aciertos en entrenamiento: 0.6484375
# Número del lote: 5205, Error del Modelo: 1.71540603327801, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5206, Error del Modelo: 1.740129246518281, Aciertos en entrenamiento: 0.625
# Número del lote: 5207, Error del Modelo: 1.785560352080478, Aciertos en entrenamiento: 0.6875
# Número del lote: 5208, Error del Modelo: 1.7969894495354044, Aciertos en entrenamiento: 0.7109375
# Número del lote: 5209, Error del Modelo: 1.6353579265796665, Aciertos en entrenamiento: 0.625
# Número del lote: 5210, Error del Modelo: 1.1942845960222845, Aciertos en entrenamiento: 0.765625
# Número del lote: 5211, Error del Modelo: 1.6016795271998912, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5212, Error del Modelo: 1.9997419462116472, Aciertos en entrenamiento: 0.59375
# Número del lote: 5213, Error del Modelo: 1.4386063955893564, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5214, Error del Modelo: 1.569830330777481, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5215, Error del Modelo: 1.7606376328114548, Aciertos en entrenamiento: 0.65625
# Número del lote: 5216, Error del Modelo: 1.8260810677282486, Aciertos en entrenamiento: 0.703125
# Número del lote: 5217, Error del Modelo: 1.6409176533601864, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5218, Error del Modelo: 1.1800572988038884, Aciertos en entrenamiento: 0.7109375
# Número del lote: 5219, Error del Modelo: 1.885875240091747, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5220, Error del Modelo: 1.9033570015320813, Aciertos en entrenamiento: 0.578125
# Número del lote: 5221, Error del Modelo: 2.1114062024770894, Aciertos en entrenamiento: 0.6328125
# Número del lote: 5222, Error del Modelo: 1.8815871573615326, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5223, Error del Modelo: 1.3151214187683062, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5224, Error del Modelo: 1.6026288880796533, Aciertos en entrenamiento: 0.7109375
# Número del lote: 5225, Error del Modelo: 1.027000094185776, Aciertos en entrenamiento: 0.7421875
# Número del lote: 5226, Error del Modelo: 1.6667486684385255, Aciertos en entrenamiento: 0.6875
# Número del lote: 5227, Error del Modelo: 1.2738678218897816, Aciertos en entrenamiento: 0.6875
# Número del lote: 5228, Error del Modelo: 1.5988650844807768, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5229, Error del Modelo: 2.0528049371852917, Aciertos en entrenamiento: 0.578125
# Número del lote: 5230, Error del Modelo: 1.44870533572333, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5231, Error del Modelo: 1.7020736145990325, Aciertos en entrenamiento: 0.625
# Número del lote: 5232, Error del Modelo: 1.4231340697005614, Aciertos en entrenamiento: 0.6796875
# Número del lote: 
Aciertos en entrenamiento: 0.6484375
# Número del lote: 5309, Error del Modelo: 1.4844905744432775, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5310, Error del Modelo: 2.2294232443566107, Aciertos en entrenamiento: 0.625
# Número del lote: 5311, Error del Modelo: 1.5385767319809343, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5312, Error del Modelo: 1.9831376049752936, Aciertos en entrenamiento: 0.65625
# Número del lote: 5313, Error del Modelo: 1.8004901794983312, Aciertos en entrenamiento: 0.640625
# Número del lote: 5314, Error del Modelo: 1.840127650491167, Aciertos en entrenamiento: 0.6171875
# Número del lote: 5315, Error del Modelo: 1.747565904845903, Aciertos en entrenamiento: 0.6328125
# Número del lote: 5316, Error del Modelo: 1.1309700844717028, Aciertos en entrenamiento: 0.7265625
# Número del lote: 5317, Error del Modelo: 1.881771931508204, Aciertos en entrenamiento: 0.640625
# Número del lote: 5318, Error del Modelo: 1.8928412806502655, Aciertos en entrenamiento: 0.625
# Número del lote: 5319, Error del Modelo: 1.1843965166042698, Aciertos en entrenamiento: 0.71875
# Número del lote: 5320, Error del Modelo: 2.20927591823405, Aciertos en entrenamiento: 0.5859375
# Número del lote: 5321, Error del Modelo: 1.5395030281286788, Aciertos en entrenamiento: 0.671875
# Número del lote: 5322, Error del Modelo: 1.8686775829325242, Aciertos en entrenamiento: 0.6171875
# Número del lote: 5323, Error del Modelo: 2.391748991247205, Aciertos en entrenamiento: 0.4609375
# Número del lote: 5324, Error del Modelo: 1.6423453091215279, Aciertos en entrenamiento: 0.640625
# Número del lote: 5325, Error del Modelo: 1.3035503571541516, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5326, Error del Modelo: 2.0087872166168053, Aciertos en entrenamiento: 0.59375
# Número del lote: 5327, Error del Modelo: 1.5014618320203545, Aciertos en entrenamiento: 0.65625
# Número del lote: 5328, Error del Modelo: 1.8715392818092682, Aciertos en entrenamiento: 0.6171875
# Número del lote: 5329, Error del Modelo: 1.3243172016325486, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5330, Error del Modelo: 1.6895010087133118, Aciertos en entrenamiento: 0.6484375
# Número del lote: 5331, Error del Modelo: 1.3836378909254097, Aciertos en entrenamiento: 0.65625
# Número del lote: 5332, Error del Modelo: 1.6847904832115363, Aciertos en entrenamiento: 0.65625
# Número del lote: 5333, Error del Modelo: 1.4927433408373103, Aciertos en entrenamiento: 0.734375
# Número del lote: 5334, Error del Modelo: 1.936862900791283, Aciertos en entrenamiento: 0.671875
# Número del lote: 5335, Error del Modelo: 1.597140476772443, Aciertos en entrenamiento: 0.640625
# Número del lote: 5336, Error del Modelo: 1.3016194562789853, Aciertos en entrenamiento: 0.671875
# Número del lote: 5337, Error del Modelo: 2.0386780803583795, Aciertos en entrenamiento: 0.640625
# Número del lote: 5338, Error del Modelo: 1.336757606805212, Aciertos en entrenamiento: 0.6875
# Número del lote: 5339, Error del Modelo: 1.368146956427678, Aciertos en entrenamiento: 0.7109375
# Número del lote: 5340, Error del Modelo: 1.3624495642965675, Aciertos en entrenamiento: 0.71875
# Número del lote: 5341, Error del Modelo: 1.5785124757649849, Aciertos en entrenamiento: 0.65625
# Número del lote: 5342, Error del Modelo: 1.863512434630132, Aciertos en entrenamiento: 0.6328125
# Número del lote: 5343, Error del Modelo: 1.4007169335115417, Aciertos en entrenamiento: 0.7109375
# Número del lote: 5344, Error del Modelo: 1.5369610461590584, Aciertos en entrenamiento: 0.65625
# Número del lote: 5345, Error del Modelo: 1.421543904458223, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5346, Error del Modelo: 1.731793950534143, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5347, Error del Modelo: 1.7977706421415154, Aciertos en entrenamiento: 0.65625
# Número del lote: 5348, Error del Modelo: 1.5253699410986032, Aciertos en entrenamiento: 0.703125
# Número del lote: 5349, Error del Modelo: 1.9565490831003194, Aciertos en entrenamiento: 0.609375
# Número del lote: 5350, Error del Modelo: 1.4945004255093743, Aciertos en entrenamiento: 0.7265625
# Número del lote: 5351, Error del Modelo: 1.6782753153351977, Aciertos en entrenamiento: 0.7109375
# Número del lote: 5352, Error del Modelo: 1.4085325210436566, Aciertos en entrenamiento: 0.7109375
# Número del lote: 5353, Error del Modelo: 1.810369887291783, Aciertos en entrenamiento: 0.6328125
# Número del lote: 5354, Error del Modelo: 1.3356460942993824, Aciertos en entrenamiento: 0.7890625
# Número del lote: 5355, Error del Modelo: 1.6960970429575877, Aciertos en entrenamiento: 0.7109375
# Número del lote: 5356, Error del Modelo: 1.1852395668532345, Aciertos en entrenamiento: 0.71875
# Número del lote: 5357, Error del Modelo: 1.3896797459189971, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5358, Error del Modelo: 1.4787175831750279, Aciertos en entrenamiento: 0.7109375
# Número del lote: 5359, Error del Modelo: 1.5510390728032222, Aciertos en entrenamiento: 0.703125
# Número del lote: 5360, Error del Modelo: 1.414831212120035, Aciertos en entrenamiento: 0.671875
# Número del lote: 5361, Error del Modelo: 1.9340058484949778, Aciertos en entrenamiento: 0.6171875
# Número del lote: 5362, Error del Modelo: 1.481924821975985, Aciertos en entrenamiento: 0.671875
# Número del lote: 5363, Error del Modelo: 1.9130784795361755, Aciertos en entrenamiento: 0.6328125
# Número del lote: 5364, Error del Modelo: 1.6405503204581249, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5365, Error del Modelo: 1.5563722809897507, Aciertos en entrenamiento: 0.640625
# Número del lote: 5366, Error del Modelo: 1.734056560035263, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5367, Error del Modelo: 2.0831476872908006, Aciertos en entrenamiento: 0.6484375
# Número del lote: 5368, Error del Modelo: 1.962988682740004, Aciertos en entrenamiento: 0.6328125
# Número del lote: 5369, Error del Modelo: 2.032154350144775, Aciertos en entrenamiento: 0.609375
# Número del lote: 5370, Error del Modelo: 1.6345196278082332, Aciertos en entrenamiento: 0.7109375
# Número del lote: 5371, Error del Modelo: 1.639214203303474, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5372, Error del Modelo: 1.7945423737570918, Aciertos en entrenamiento: 0.65625
# Número del lote: 5373, Error del Modelo: 1.2207832919174668, Aciertos en entrenamiento: 0.7109375
# Número del lote: 5374, Error del Modelo: 1.5758221058044704, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5375, Error del Modelo: 1.4812964167423093, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5376, Error del Modelo: 1.8430872098514417, Aciertos en entrenamiento: 0.671875
# Número del lote: 5377, Error del Modelo: 1.8429879866886039, Aciertos en entrenamiento: 0.671875
# Número del lote: 5378, Error del Modelo: 1.8192673409915723, Aciertos en entrenamiento: 0.65625
# Número del lote: 5379, Error del Modelo: 1.4902506593220564, Aciertos en entrenamiento: 0.71875
# Número del lote: 5380, Error del Modelo: 2.3634286294924416, Aciertos en entrenamiento: 0.640625
# Número del lote: 5381, Error del Modelo: 1.539194960169953, Aciertos en entrenamiento: 0.7109375
# Número del lote: 5382, Error del Modelo: 1.8008560318164044, Aciertos en entrenamiento: 0.6015625
# Número del lote: 5383, Error del Modelo: 2.529695556796271, Aciertos en entrenamiento: 0.5859375
# Número del lote: 5384, Error del Modelo: 1.6348711016551576, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5385, Error del Modelo: 1.4854323135143388, Aciertos en entrenamiento: 0.6875
# Número del lote: 5386, Error del Modelo: 1.6796304004215399, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5387, Error del Modelo: 1.3932411121063013, Aciertos en entrenamiento: 0.65625
# Número del lote: 5388, Error del Modelo: 1.9429630141156367, Aciertos en entrenamiento: 0.6484375
# Número del lote: 5389, Error del Modelo: 1.326428179603652, Aciertos en entrenamiento: 0.6875
# Número del lote: 5390, Error del Modelo: 1.5022176215681111, Aciertos en entrenamiento: 0.6328125
# Número del lote: 5391, Error del Modelo: 1.6352484113614767, Aciertos en entrenamiento: 0.71875
# Número del lote: 5392, Error del Modelo: 2.452194794513212, Aciertos en entrenamiento: 0.6171875
# Número del lote: 5393, Error del Modelo: 1.8402412410964475, Aciertos en entrenamiento: 0.640625
# Número del lote: 5394, Error del Modelo: 1.5403833300208483, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5395, Error del Modelo: 1.7252947495194866, Aciertos en entrenamiento: 0.6875
# Número del lote: 5396, Error del Modelo: 1.7168766292791564, Aciertos en entrenamiento: 0.640625
# Número del lote: 5397, Error del Modelo: 1.303291269040064, Aciertos en entrenamiento: 0.71875
# Número del lote: 5398, Error del Modelo: 1.0853931237107568, Aciertos en entrenamiento: 0.7578125
# Número del lote: 5399, Error del Modelo: 1.5088323274800024, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5400, Error del Modelo: 1.716609939805897, Aciertos en entrenamiento: 0.6171875
# Número del lote: 5401, Error del Modelo: 1.8315487986056564, Aciertos en entrenamiento: 0.65625
# Número del lote: 5402, Error del Modelo: 1.442472077669747, Aciertos en entrenamiento: 0.71875
# Número del lote: 5403, Error del Modelo: 1.5087198678969402, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5404, Error del Modelo: 1.4858133503136992, Aciertos en entrenamiento: 0.7265625
# Número del lote: 5405, Error del Modelo: 1.5683808919557336, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5406, Error del Modelo: 1.4022582693792658, Aciertos en entrenamiento: 0.7109375
# Número del lote: 5407, Error del Modelo: 1.9045845898924791, Aciertos en entrenamiento: 0.6484375
# Número del lote: 5408, Error del Modelo: 1.536948719645399, Aciertos en entrenamiento: 0.671875
# Número del lote: 5409, Error del Modelo: 1.2527778523467843, Aciertos en entrenamiento: 0.734375
# Número del lote: 5410, Error del Modelo: 1.5501339531760494, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5411, Error del Modelo: 1.3497972413823696, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5412, Error del Modelo: 1.4661772496596481, Aciertos en entrenamiento: 0.71875
# Número del lote: 5413, Error del Modelo: 1.8555912878506893, Aciertos en entrenamiento: 0.6328125
# Número del lote: 5414, Error del Modelo: 1.6040094009158954, Aciertos en entrenamiento: 0.65625
# Número del lote: 5415, Error del Modelo: 1.4909176419389383, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5416, Error del Modelo: 2.169320852520633, Aciertos en entrenamiento: 0.640625
# Número del lote: 5417, Error del Modelo: 1.5332662069080536, Aciertos en entrenamiento: 0.6484375
# Número del lote: 5418, Error del Modelo: 1.7911717507377316, Aciertos en entrenamiento: 0.6328125
# Número del lote: 5419, Error del Modelo: 1.8200650106674543, Aciertos en entrenamiento: 0.6484375
# Número del lote: 5420, Error del Modelo: 1.6581838321576994, Aciertos en entrenamiento: 0.640625
# Número del lote: 5421, Error del Modelo: 1.5572639349252912, Aciertos en entrenamiento: 0.65625
# Número del lote: 5422, Error del Modelo: 1.9936184118508256, Aciertos en entrenamiento: 0.6328125
# Número del lote: 5423, Error del Modelo: 1.3543597152364566, Aciertos en entrenamiento: 0.703125
# Número del lote: 5424, Error del Modelo: 1.5584479912861626, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5425, Error del Modelo: 1.9733536889367567, Aciertos en entrenamiento: 0.578125
# Número del lote: 5426, Error del Modelo: 1.8187318379184498, Aciertos en entrenamiento: 0.640625
# Número del lote: 5427, Error del Modelo: 2.0659551375697873, Aciertos en entrenamiento: 0.6015625
# Número del lote: 5428, Error del Modelo: 1.4962876226861508, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5429, Error del Modelo: 1.8391820156970753, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5430, Error del Modelo: 1.1425020259588499, Aciertos en entrenamiento: 0.7421875
# Número del lote: 5431, Error del Modelo: 1.6180458355300091, Aciertos en entrenamiento: 0.65625
# Número del lote: 5432, Error del Modelo: 1.6220136688874414, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5433, Error del Modelo: 1.860069790003062, Aciertos en entrenamiento: 0.609375
# Número del lote: 5434, Error del Modelo: 1.7128217912795687, Aciertos en entrenamiento: 0.65625
# Número del lote: 5435, Error del Modelo: 1.1916977737830612, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5436, Error del Modelo: 1.511572642308134, Aciertos en entrenamiento: 0.7109375
# Número del lote: 5437, Error del Modelo: 1.6118418242860255, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5438, Error del Modelo: 1.509290222766479, Aciertos en entrenamiento: 0.6875
# Número del lote: 5439, Error del Modelo: 1.5716582033799424, Aciertos en entrenamiento: 0.6875
# Número del lote: 5440, Error del Modelo: 1.5353951801798544, Aciertos en entrenamiento: 0.671875
# Número del lote: 5441, Error del Modelo: 1.161814324686437, Aciertos en entrenamiento: 0.796875
# Número del lote: 5442, Error del Modelo: 1.7761167984104875, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5443, Error del Modelo: 2.265910422695881, Aciertos en entrenamiento: 0.59375
# Número del lote: 5444, Error del Modelo: 1.401159913379109, Aciertos en entrenamiento: 0.671875
# Número del lote: 5445, Error del Modelo: 1.8784761089344135, Aciertos en entrenamiento: 0.671875
# Número del lote: 5446, Error del Modelo: 2.174348310345927, Aciertos en entrenamiento: 0.5859375
# Número del lote: 5447, Error del Modelo: 1.8050711849486727, Aciertos en entrenamiento: 0.65625
# Número del lote: 5448, Error del Modelo: 1.4325878344428236, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5449, Error del Modelo: 1.5778897603763915, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5450, Error del Modelo: 1.659010285273511, Aciertos en entrenamiento: 0.625
# Número del lote: 5451, Error del Modelo: 1.22958181171458, Aciertos en entrenamiento: 0.7421875
# Número del lote: 5452, Error del Modelo: 1.7428811024731035, Aciertos en entrenamiento: 0.65625
# Número del lote: 5453, Error del Modelo: 1.8276980865269419, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5454, Error del Modelo: 1.791394444496206, Aciertos en entrenamiento: 0.640625
# Número del lote: 5455, Error del Modelo: 1.4430544551200661, Aciertos en entrenamiento: 0.640625
# Número del lote: 5456, Error del Modelo: 1.3288462373863494, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5457, Error del Modelo: 1.354141480158336, Aciertos en entrenamiento: 0.7578125
# Número del lote: 5458, Error del Modelo: 1.691411836799279, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5459, Error del Modelo: 1.830676160208467, Aciertos en entrenamiento: 0.640625
# Número del lote: 5460, Error del Modelo: 2.408036787865398, Aciertos en entrenamiento: 0.625
# Número del lote: 5461, Error del Modelo: 1.946221745529022, Aciertos en entrenamiento: 0.609375
# Número del lote: 5462, Error del Modelo: 2.2344535386916506, Aciertos en entrenamiento: 0.5859375
# Número del lote: 5463, Error del Modelo: 1.3194872722281474, Aciertos en entrenamiento: 0.6875
# Número del lote: 5464, Error del Modelo: 1.9847447028641265, Aciertos en entrenamiento: 0.6171875
# Número del lote: 5465, Error del Modelo: 1.150675895092653, Aciertos en entrenamiento: 0.71875
# Número del lote: 5466, Error del Modelo: 1.4656017168916082, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5467, Error del Modelo: 1.5528117918121036, Aciertos en entrenamiento: 0.6484375
# Número del lote: 5468, Error del Modelo: 1.8423885264588908, Aciertos en entrenamiento: 0.6328125
# Número del lote: 5469, Error del Modelo: 2.04847180565785, Aciertos en entrenamiento: 0.6171875
# Número del lote: 5470, Error del Modelo: 1.847301882289044, Aciertos en entrenamiento: 0.671875
# Número del lote: 5471, Error del Modelo: 1.95699359362768, Aciertos en entrenamiento: 0.625
# Número del lote: 5472, Error del Modelo: 1.6473409629727866, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5473, Error del Modelo: 1.4781263128003097, Aciertos en entrenamiento: 0.671875
# Número del lote: 5474, Error del Modelo: 1.4575955154043019, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5475, Error del Modelo: 1.8070519073274451, Aciertos en entrenamiento: 0.6328125
# Número del lote: 5476, Error del Modelo: 1.7334809442146057, Aciertos en entrenamiento: 0.6015625
# Número del lote: 5477, Error del Modelo: 1.7363891321834646, Aciertos en entrenamiento: 0.6328125
# Número del lote: 5478, Error del Modelo: 1.3183750099103222, Aciertos en entrenamiento: 0.6640625
# Número del lote: 5479, Error del Modelo: 1.6917769863195389, Aciertos en entrenamiento: 0.6484375
# Número del lote: 5480, Error del Modelo: 1.7225368898098763, Aciertos en entrenamiento: 0.671875
# Número del lote: 5481, Error del Modelo: 2.048550370325075, Aciertos en entrenamiento: 0.6171875
# Número del lote: 5482, Error del Modelo: 1.377932163845774, Aciertos en entrenamiento: 0.703125
# Número del lote: 5483, Error del Modelo: 1.6073910048791118, Aciertos en entrenamiento: 0.65625
# Número del lote: 5484, Error del Modelo: 1.6379765920050575, Aciertos en entrenamiento: 0.6875
# Número del lote: 5485, Error del Modelo: 1.7999725682944727, Aciertos en entrenamiento: 0.6328125
# Número del lote: 5486, Error del Modelo: 1.0826951747662936, Aciertos en entrenamiento: 0.734375
# Número del lote: 5487, Error del Modelo: 1.496448829396827, Aciertos en entrenamiento: 0.6796875
# Número del lote: 5488, Error del Modelo: 1.5030671066462342, Aciertos en entrenamiento: 0.671875
# Número del lote: 5489, Error del Modelo: 1.421859823174445, Aciertos en entrenamiento: 0.65625
# Número del lote: 5490, Error del Modelo: 1.474683332337128, Aciertos en entrenamiento: 0.734375
# Número del lote: 5491, Error del Modelo: 1.4322948046817428, Aciertos en entrenamiento: 0.7734375
# Número del lote: 5492, Error del Modelo: 1.5238994165143105, Aciertos en entrenamiento: 0.6953125
# Número del lote: 5493, Error del Modelo: 1.1351438668359322, Aciertos en entrenamiento: 0.734375
# Número del lote: 5494, Error del Modelo: 2.091814636903954, Aciertos en entrenamiento: 0.6171875
# Número del lote: 5495, Error del Modelo: 1.4224520769452917, Aciertos en entrenamiento: 0.6796875
# ...
# Número del lote: 9836, Error del Modelo: 1.1385028062458935, Aciertos en entrenamiento: 0.7421875
# Número del lote: 9837, Error del Modelo: 1.3985924671874976, Aciertos en entrenamiento: 0.7578125
# Número del lote: 9838, Error del Modelo: 1.1555230987060625, Aciertos en entrenamiento: 0.7578125
# Número del lote: 9839, Error del Modelo: 1.0316582531444751, Aciertos en entrenamiento: 0.7890625
# Número del lote: 9840, Error del Modelo: 1.441079467708838, Aciertos en entrenamiento: 0.6796875
# Número del lote: 9841, Error del Modelo: 1.5089984063994624, Aciertos en entrenamiento: 0.71875
# Número del lote: 9842, Error del Modelo: 1.415559766973865, Aciertos en entrenamiento: 0.78125
# Número del lote: 9843, Error del Modelo: 1.5941374517682625, Aciertos en entrenamiento: 0.65625
# Número del lote: 9844, Error del Modelo: 1.0987405909103787, Aciertos en entrenamiento: 0.7421875
# Número del lote: 9845, Error del Modelo: 1.2471366226031566, Aciertos en entrenamiento: 0.7109375
# Número del lote: 9846, Error del Modelo: 1.2319955875770003, Aciertos en entrenamiento: 0.765625
# Número del lote: 9847, Error del Modelo: 1.47789415624667, Aciertos en entrenamiento: 0.71875
# Número del lote: 9848, Error del Modelo: 0.9756169880133555, Aciertos en entrenamiento: 0.7578125
# Número del lote: 9849, Error del Modelo: 1.307733094730141, Aciertos en entrenamiento: 0.71875
# Número del lote: 9850, Error del Modelo: 1.6805227544534607, Aciertos en entrenamiento: 0.71875
# Número del lote: 9851, Error del Modelo: 1.561944593744937, Aciertos en entrenamiento: 0.703125
# Número del lote: 9852, Error del Modelo: 1.5972806443166738, Aciertos en entrenamiento: 0.5859375
# Número del lote: 9853, Error del Modelo: 1.1038965525603972, Aciertos en entrenamiento: 0.7578125
# Número del lote: 9854, Error del Modelo: 1.315651720482994, Aciertos en entrenamiento: 0.65625
# Número del lote: 9855, Error del Modelo: 1.3910525959404314, Aciertos en entrenamiento: 0.6875
# Número del lote: 9856, Error del Modelo: 1.5961155136901588, Aciertos en entrenamiento: 0.6875
# Número del lote: 9857, Error del Modelo: 1.0470971824690345, Aciertos en entrenamiento: 0.765625
# Número del lote: 9858, Error del Modelo: 1.4017393323022858, Aciertos en entrenamiento: 0.6484375
# Número del lote: 9859, Error del Modelo: 1.6029138199943462, Aciertos en entrenamiento: 0.7421875
# Número del lote: 9860, Error del Modelo: 1.4674066515421633, Aciertos en entrenamiento: 0.703125
# Número del lote: 9861, Error del Modelo: 1.1448143144908698, Aciertos en entrenamiento: 0.7734375
# Número del lote: 9862, Error del Modelo: 1.2962017888203143, Aciertos en entrenamiento: 0.7265625
# Número del lote: 9863, Error del Modelo: 1.4932350107928332, Aciertos en entrenamiento: 0.7421875
# Número del lote: 9864, Error del Modelo: 1.7022196691627758, Aciertos en entrenamiento: 0.625
# Número del lote: 9865, Error del Modelo: 1.3908413121605625, Aciertos en entrenamiento: 0.7265625
# Número del lote: 9866, Error del Modelo: 1.3631376099239827, Aciertos en entrenamiento: 0.7578125
# Número del lote: 9867, Error del Modelo: 1.3115363559954223, Aciertos en entrenamiento: 0.7734375
# Número del lote: 9868, Error del Modelo: 1.2396687232982484, Aciertos en entrenamiento: 0.6640625
# Número del lote: 9869, Error del Modelo: 0.9024189078389191, Aciertos en entrenamiento: 0.71875
# Número del lote: 9870, Error del Modelo: 1.3423608636536117, Aciertos en entrenamiento: 0.7109375
# Número del lote: 9871, Error del Modelo: 1.1132780519886616, Aciertos en entrenamiento: 0.7421875
# Número del lote: 9872, Error del Modelo: 1.685420858844591, Aciertos en entrenamiento: 0.6640625
# Número del lote: 9873, Error del Modelo: 1.2126070033799676, Aciertos en entrenamiento: 0.71875
# Número del lote: 9874, Error del Modelo: 1.1122849621787776, Aciertos en entrenamiento: 0.765625
# Número del lote: 9875, Error del Modelo: 1.718638302401831, Aciertos en entrenamiento: 0.640625
# Número del lote: 9876, Error del Modelo: 1.2338129579974995, Aciertos en entrenamiento: 0.703125
# Número del lote: 9877, Error del Modelo: 1.312139593153808, Aciertos en entrenamiento: 0.7109375
# Número del lote: 9878, Error del Modelo: 1.3748149753160859, Aciertos en entrenamiento: 0.734375
# Número del lote: 9879, Error del Modelo: 1.378256557350334, Aciertos en entrenamiento: 0.6953125
# Número del lote: 9880, Error del Modelo: 1.8193114884670483, Aciertos en entrenamiento: 0.6796875
# Número del lote: 9881, Error del Modelo: 0.8444304826818283, Aciertos en entrenamiento: 0.7265625
# Número del lote: 9882, Error del Modelo: 1.4012458674809163, Aciertos en entrenamiento: 0.71875
# Número del lote: 9883, Error del Modelo: 1.169209971490913, Aciertos en entrenamiento: 0.6796875
# Número del lote: 9884, Error del Modelo: 1.6041959432013835, Aciertos en entrenamiento: 0.65625
# Número del lote: 9885, Error del Modelo: 1.5886022681052019, Aciertos en entrenamiento: 0.6875
# Número del lote: 9886, Error del Modelo: 1.2083636307098715, Aciertos en entrenamiento: 0.71875
# Número del lote: 9887, Error del Modelo: 1.3709737946984388, Aciertos en entrenamiento: 0.7421875
# Número del lote: 9888, Error del Modelo: 1.0431840856681265, Aciertos en entrenamiento: 0.7265625
# Número del lote: 9889, Error del Modelo: 1.4175055216941286, Aciertos en entrenamiento: 0.6953125
# Número del lote: 9890, Error del Modelo: 1.3489332620471228, Aciertos en entrenamiento: 0.75
# Número del lote: 9891, Error del Modelo: 1.290261666691364, Aciertos en entrenamiento: 0.6875
# Número del lote: 9892, Error del Modelo: 1.099384791618649, Aciertos en entrenamiento: 0.765625
# Número del lote: 9893, Error del Modelo: 1.3486491668469567, Aciertos en entrenamiento: 0.7109375
# Número del lote: 9894, Error del Modelo: 1.336320525042017, Aciertos en entrenamiento: 0.703125
# Número del lote: 9895, Error del Modelo: 1.3595783636238126, Aciertos en entrenamiento: 0.7109375
# Número del lote: 9896, Error del Modelo: 1.4425953567339718, Aciertos en entrenamiento: 0.6796875
# Número del lote: 9897, Error del Modelo: 1.4547928286128826, Aciertos en entrenamiento: 0.7109375
# Número del lote: 9898, Error del Modelo: 1.954751534234382, Aciertos en entrenamiento: 0.6875
# Número del lote: 9899, Error del Modelo: 1.2503070056486691, Aciertos en entrenamiento: 0.765625
# Número del lote: 9900, Error del Modelo: 1.1285851946004262, Aciertos en entrenamiento: 0.7109375
# Número del lote: 9901, Error del Modelo: 1.3501641091591603, Aciertos en entrenamiento: 0.71875
# Número del lote: 9902, Error del Modelo: 0.7723573284284752, Aciertos en entrenamiento: 0.8125
# Número del lote: 9903, Error del Modelo: 1.0530659065195633, Aciertos en entrenamiento: 0.765625
# Número del lote: 9904, Error del Modelo: 1.2454885811026286, Aciertos en entrenamiento: 0.6953125
# Número del lote: 9905, Error del Modelo: 1.5268921394758455, Aciertos en entrenamiento: 0.6640625
# Número del lote: 9906, Error del Modelo: 1.3455806810933264, Aciertos en entrenamiento: 0.7109375
# Número del lote: 9907, Error del Modelo: 1.168517554012588, Aciertos en entrenamiento: 0.7265625
# Número del lote: 9908, Error del Modelo: 1.2839225783369588, Aciertos en entrenamiento: 0.7109375
# Número del lote: 9909, Error del Modelo: 0.9590144875348764, Aciertos en entrenamiento: 0.7890625
# Número del lote: 9910, Error del Modelo: 1.0757453284240701, Aciertos en entrenamiento: 0.7109375
# Número del lote: 9911, Error del Modelo: 1.5214169401904212, Aciertos en entrenamiento: 0.703125
# Número del lote: 9912, Error del Modelo: 0.9493264754741629, Aciertos en entrenamiento: 0.71875
# Número del lote: 9913, Error del Modelo: 1.2681701740295606, Aciertos en entrenamiento: 0.703125
# Número del lote: 9914, Error del Modelo: 0.903414337998342, Aciertos en entrenamiento: 0.7578125
# Número del lote: 9915, Error del Modelo: 1.0422065169583676, Aciertos en entrenamiento: 0.71875
# Número del lote: 9916, Error del Modelo: 1.5801079386122243, Aciertos en entrenamiento: 0.75
# Número del lote: 9917, Error del Modelo: 1.6854828039625467, Aciertos en entrenamiento: 0.671875
# Número del lote: 9918, Error del Modelo: 1.1016677976171152, Aciertos en entrenamiento: 0.7265625
# Número del lote: 9919, Error del Modelo: 1.419427489251708, Aciertos en entrenamiento: 0.7265625
# Número del lote: 9920, Error del Modelo: 1.1277631414396208, Aciertos en entrenamiento: 0.7578125
# Número del lote: 9921, Error del Modelo: 1.4358791517803215, Aciertos en entrenamiento: 0.734375
# Número del lote: 9922, Error del Modelo: 1.0682636610709102, Aciertos en entrenamiento: 0.734375
# Número del lote: 9923, Error del Modelo: 1.4907630003972432, Aciertos en entrenamiento: 0.71875
# Número del lote: 9924, Error del Modelo: 1.836068809151247, Aciertos en entrenamiento: 0.6484375
# Número del lote: 9925, Error del Modelo: 1.033115136294334, Aciertos en entrenamiento: 0.71875
# Número del lote: 9926, Error del Modelo: 0.7133599971713164, Aciertos en entrenamiento: 0.75
# Número del lote: 9927, Error del Modelo: 1.102951418280061, Aciertos en entrenamiento: 0.7578125
# Número del lote: 9928, Error del Modelo: 1.2406553779992806, Aciertos en entrenamiento: 0.6796875
# Número del lote: 9929, Error del Modelo: 1.4587047508738649, Aciertos en entrenamiento: 0.6796875
# Número del lote: 9930, Error del Modelo: 1.2365331866329634, Aciertos en entrenamiento: 0.7421875
# Número del lote: 9931, Error del Modelo: 1.4583808715305215, Aciertos en entrenamiento: 0.6875
# Número del lote: 9932, Error del Modelo: 1.739591023146271, Aciertos en entrenamiento: 0.6484375
# Número del lote: 9933, Error del Modelo: 1.2323981209933115, Aciertos en entrenamiento: 0.734375
# Número del lote: 9934, Error del Modelo: 1.3489130519994694, Aciertos en entrenamiento: 0.7109375
# Número del lote: 9935, Error del Modelo: 1.2670973528297305, Aciertos en entrenamiento: 0.6953125
# Número del lote: 9936, Error del Modelo: 1.4266609967023087, Aciertos en entrenamiento: 0.6796875
# Número del lote: 9937, Error del Modelo: 1.0543274973196088, Aciertos en entrenamiento: 0.765625
# Número del lote: 9938, Error del Modelo: 1.437726088823483, Aciertos en entrenamiento: 0.703125
# Número del lote: 9939, Error del Modelo: 1.4481374919641627, Aciertos en entrenamiento: 0.734375
# Número del lote: 9940, Error del Modelo: 1.3188058072548308, Aciertos en entrenamiento: 0.625
# Número del lote: 9941, Error del Modelo: 1.3485260410390025, Aciertos en entrenamiento: 0.7109375
# Número del lote: 9942, Error del Modelo: 1.063528376009435, Aciertos en entrenamiento: 0.7421875
# Número del lote: 9943, Error del Modelo: 1.5203455678528741, Aciertos en entrenamiento: 0.6875
# Número del lote: 9944, Error del Modelo: 1.802475205549717, Aciertos en entrenamiento: 0.609375
# Número del lote: 9945, Error del Modelo: 1.8083089694994348, Aciertos en entrenamiento: 0.6796875
# Número del lote: 9946, Error del Modelo: 1.1128984734497032, Aciertos en entrenamiento: 0.7109375
# Número del lote: 9947, Error del Modelo: 1.9114180089175075, Aciertos en entrenamiento: 0.6171875
# Número del lote: 9948, Error del Modelo: 2.0493621059408023, Aciertos en entrenamiento: 0.609375
# Número del lote: 9949, Error del Modelo: 1.2123203804437497, Aciertos en entrenamiento: 0.734375
# Número del lote: 9950, Error del Modelo: 0.9176166366100172, Aciertos en entrenamiento: 0.78125
# Número del lote: 9951, Error del Modelo: 1.3388945189059442, Aciertos en entrenamiento: 0.7421875
# Número del lote: 9952, Error del Modelo: 0.948306210079853, Aciertos en entrenamiento: 0.7421875
# Número del lote: 9953, Error del Modelo: 1.39487424065163, Aciertos en entrenamiento: 0.7421875
# Número del lote: 9954, Error del Modelo: 1.5080368135140623, Aciertos en entrenamiento: 0.640625
# Número del lote: 9955, Error del Modelo: 1.0554093899281476, Aciertos en entrenamiento: 0.7734375
# Número del lote: 9956, Error del Modelo: 1.5370223554203841, Aciertos en entrenamiento: 0.6953125
# Número del lote: 9957, Error del Modelo: 1.673799414858164, Aciertos en entrenamiento: 0.671875
# Número del lote: 9958, Error del Modelo: 1.3882924571600834, Aciertos en entrenamiento: 0.75
# Número del lote: 9959, Error del Modelo: 1.137069290071104, Aciertos en entrenamiento: 0.734375
# Número del lote: 9960, Error del Modelo: 1.1390642902540709, Aciertos en entrenamiento: 0.734375
# Número del lote: 9961, Error del Modelo: 1.2906889052100798, Aciertos en entrenamiento: 0.703125
# Número del lote: 9962, Error del Modelo: 1.5088335969480682, Aciertos en entrenamiento: 0.625
# Número del lote: 9963, Error del Modelo: 1.8494348965994185, Aciertos en entrenamiento: 0.6796875
# Número del lote: 9964, Error del Modelo: 1.3860682552810053, Aciertos en entrenamiento: 0.7109375
# Número del lote: 9965, Error del Modelo: 1.2936151633798683, Aciertos en entrenamiento: 0.671875
# Número del lote: 9966, Error del Modelo: 1.1527823917231816, Aciertos en entrenamiento: 0.734375
# Número del lote: 9967, Error del Modelo: 1.61557735016867, Aciertos en entrenamiento: 0.6953125
# Número del lote: 9968, Error del Modelo: 1.5011326974507941, Aciertos en entrenamiento: 0.6640625
# Número del lote: 9969, Error del Modelo: 1.767769433461794, Aciertos en entrenamiento: 0.625
# Número del lote: 9970, Error del Modelo: 1.3315718823718357, Aciertos en entrenamiento: 0.6953125
# Número del lote: 9971, Error del Modelo: 0.8985253863516041, Aciertos en entrenamiento: 0.765625
# Número del lote: 9972, Error del Modelo: 1.1331158201093834, Aciertos en entrenamiento: 0.7421875
# Número del lote: 9973, Error del Modelo: 1.6443354929515475, Aciertos en entrenamiento: 0.6953125
# Número del lote: 9974, Error del Modelo: 1.2920367158242607, Aciertos en entrenamiento: 0.671875
# Número del lote: 9975, Error del Modelo: 0.9805028446086034, Aciertos en entrenamiento: 0.71875
# Número del lote: 9976, Error del Modelo: 1.0713977770066596, Aciertos en entrenamiento: 0.7421875
# Número del lote: 9977, Error del Modelo: 1.0416314906935051, Aciertos en entrenamiento: 0.71875
# Número del lote: 9978, Error del Modelo: 1.4389550890717753, Aciertos en entrenamiento: 0.7734375
# Número del lote: 9979, Error del Modelo: 1.346815880141681, Aciertos en entrenamiento: 0.6875
# Número del lote: 9980, Error del Modelo: 1.0513957885073693, Aciertos en entrenamiento: 0.7578125
# Número del lote: 9981, Error del Modelo: 1.0469458067353141, Aciertos en entrenamiento: 0.7421875
# Número del lote: 9982, Error del Modelo: 1.276263365021528, Aciertos en entrenamiento: 0.734375
# Número del lote: 9983, Error del Modelo: 1.2250032550925662, Aciertos en entrenamiento: 0.671875
# Número del lote: 9984, Error del Modelo: 1.4526707515813841, Aciertos en entrenamiento: 0.7421875
# Número del lote: 9985, Error del Modelo: 1.5533412323378748, Aciertos en entrenamiento: 0.6640625
# Número del lote: 9986, Error del Modelo: 1.7076714789544558, Aciertos en entrenamiento: 0.6171875
# Número del lote: 9987, Error del Modelo: 1.6738968991454342, Aciertos en entrenamiento: 0.671875
# Número del lote: 9988, Error del Modelo: 1.0698135713169807, Aciertos en entrenamiento: 0.7421875
# Número del lote: 9989, Error del Modelo: 1.2076319855284747, Aciertos en entrenamiento: 0.6953125
# Número del lote: 9990, Error del Modelo: 1.805070613356143, Aciertos en entrenamiento: 0.6796875
# Número del lote: 9991, Error del Modelo: 1.5913729977402489, Aciertos en entrenamiento: 0.6953125
# Número del lote: 9992, Error del Modelo: 1.5400467517474588, Aciertos en entrenamiento: 0.6796875
# Número del lote: 9993, Error del Modelo: 1.5443445375815101, Aciertos en entrenamiento: 0.703125
# Número del lote: 9994, Error del Modelo: 1.1082867412158803, Aciertos en entrenamiento: 0.7578125
# Número del lote: 9995, Error del Modelo: 1.4590935571853458, Aciertos en entrenamiento: 0.6953125
# Número del lote: 9996, Error del Modelo: 1.129750285018099, Aciertos en entrenamiento: 0.6953125
# Número del lote: 9997, Error del Modelo: 1.0358325806703506, Aciertos en entrenamiento: 0.7265625
# Número del lote: 9998, Error del Modelo: 0.925077514114112, Aciertos en entrenamiento: 0.75
# Número del lote: 9999, Error del Modelo: 1.2281638964123924, Aciertos en entrenamiento: 0.7734375
# Número del lote: 10000, Error del Modelo: 1.39407899645497, Aciertos en entrenamiento: 0.7421875

# %% [markdown]
# ## Provando el modelo

# %% [markdown]
# Para saber si nuestro modelo quedo bien entrenado, hacemos los calculos con los datos de prueba

# %%
dataset_teste = tf.data.Dataset.from_tensor_slices((x_teste,y_teste))
dataset_teste = dataset_teste.repeat().shuffle(x_teste.shape[0]).batch(tamaño_lote)

# %% [markdown]
# Realizamos las predicciones y los calculos de acierto

# %%
print("iniciando la evaluación de los testes, espere....")
for indice_lote,(lote_x_teste, lote_y_teste) in enumerate(dataset_teste.take(numero_de_lotes),1):
  y_pred = logistic_regression(lote_x_teste)
  acc = aciertos(lote_y_teste, y_pred)
  acierto = tf.reduce_mean(tf.cast(acc,tf.float64))*100
  
print("La tasa de acierto en teste {} %".format(acierto))
# Out:
# iniciando la evaluación de los testes, espere....
# La tasa de acierto en teste 76.5625 %

# %% [markdown]
# Realizamos las pruebas con tres imàgenes aleatorias

# %%
dataset_teste = tf.data.Dataset.from_tensor_slices((x_teste,y_teste))
dataset_teste = dataset_teste.repeat().shuffle(x_teste.shape[0]).batch(3)

# %%
for indice_lote, (lote_xs, lote_ys) in enumerate(dataset_teste.take(3), 1):
    print("\nClase verdadera:", lote_ys)
    y_pred = tf.math.argmax(logistic_regression(lote_xs), axis = 1)
    print("Classe Predicha:", y_pred)
# Out:
# Clase verdadera: tf.Tensor([2 2 5], shape=(3,), dtype=uint8)
# Classe Predicha: tf.Tensor([2 6 8], shape=(3,), dtype=int64)
#
# Clase verdadera: tf.Tensor([3 6 8], shape=(3,), dtype=uint8)
# Classe Predicha: tf.Tensor([1 2 8], shape=(3,), dtype=int64)
#
# Clase verdadera: tf.Tensor([8 3 5], shape=(3,), dtype=uint8)
# Classe Predicha: tf.Tensor([8 3 5], shape=(3,), dtype=int64)
